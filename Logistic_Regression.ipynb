# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /home/popeye/.conda/envs/PythonData/lib/python3.6/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /home/popeye/.conda/envs/PythonData/lib/python3.6/site-packages (from sklearn) (0.21.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /home/popeye/.conda/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.16.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/popeye/.conda/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /home/popeye/.conda/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.3.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /home/popeye/.conda/envs/PythonData/lib/python3.6/site-packages (0.13.2)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_disposition', 'koi_prad', 'koi_teq', 'koi_insol']]

# %%
selected_features.head()
# Out:
#   koi_disposition  koi_prad  koi_teq  koi_insol
# 0       CONFIRMED      2.83      443       9.11
# 1  FALSE POSITIVE     14.60      638      39.30
# 2  FALSE POSITIVE     33.46     1395     891.96
# 3       CONFIRMED      2.75     1406     926.16
# 4       CONFIRMED      2.77     1160     427.65

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = selected_features.drop("koi_disposition", axis=1)
y = selected_features["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 3) (6991,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
X_train.head()
# Out:
#       koi_prad  koi_teq  koi_insol
# 4002    576.14      262       1.11
# 4246      6.77     1551    1361.22
# 548      38.93      907     160.14
# 3953     33.24      361       4.00
# 2362      2.26      524      17.75

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='newton-cg', multi_class='auto')
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.2412740797253481
# Testing Data Score: 0.2414187643020595

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CANDIDATE'
#  'CONFIRMED' 'CANDIDATE' 'FALSE POSITIVE' 'CANDIDATE' 'CONFIRMED'
#  'FALSE POSITIVE']
# First 10 Actual labels: ['CANDIDATE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CONFIRMED']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#           Prediction          Actual
# 0     FALSE POSITIVE       CANDIDATE
# 1     FALSE POSITIVE  FALSE POSITIVE
# 2     FALSE POSITIVE  FALSE POSITIVE
# 3          CANDIDATE       CANDIDATE
# 4          CONFIRMED  FALSE POSITIVE
# 5          CANDIDATE       CONFIRMED
# 6     FALSE POSITIVE  FALSE POSITIVE
# 7          CANDIDATE  FALSE POSITIVE
# 8          CONFIRMED       CONFIRMED
# 9     FALSE POSITIVE       CONFIRMED
# 10    FALSE POSITIVE  FALSE POSITIVE
# 11    FALSE POSITIVE  FALSE POSITIVE
# 12    FALSE POSITIVE       CONFIRMED
# 13         CONFIRMED  FALSE POSITIVE
# 14         CONFIRMED       CONFIRMED
# 15         CONFIRMED       CANDIDATE
# 16    FALSE POSITIVE  FALSE POSITIVE
# 17    FALSE POSITIVE  FALSE POSITIVE
# 18    FALSE POSITIVE  FALSE POSITIVE
# 19    FALSE POSITIVE  FALSE POSITIVE
# 20    FALSE POSITIVE  FALSE POSITIVE
# 21         CONFIRMED       CONFIRMED
# 22         CONFIRMED  FALSE POSITIVE
# 23         CONFIRMED       CANDIDATE
# 24         CONFIRMED       CANDIDATE
# 25         CANDIDATE       CONFIRMED
# 26         CONFIRMED       CONFIRMED
# 27         CANDIDATE       CONFIRMED
# 28         CONFIRMED       CANDIDATE
# 29         CANDIDATE       CANDIDATE
# ...              ...             ...
# 1718  FALSE POSITIVE  FALSE POSITIVE
# 1719  FALSE POSITIVE  FALSE POSITIVE
# 1720       CONFIRMED       CONFIRMED
# 1721  FALSE POSITIVE  FALSE POSITIVE
# 1722       CANDIDATE       CANDIDATE
# 1723       CONFIRMED       CONFIRMED
# 1724  FALSE POSITIVE  FALSE POSITIVE
# 1725  FALSE POSITIVE  FALSE POSITIVE
# 1726  FALSE POSITIVE  FALSE POSITIVE
# 1727       CANDIDATE       CONFIRMED
# 1728       CONFIRMED       CONFIRMED
# 1729       CONFIRMED       CANDIDATE
# 1730       CONFIRMED       CANDIDATE
# 1731       CONFIRMED       CONFIRMED
# 1732       CONFIRMED  FALSE POSITIVE
# 1733       CONFIRMED       CANDIDATE
# 1734       CONFIRMED  FALSE POSITIVE
# 1735       CONFIRMED       CANDIDATE
# 1736       CONFIRMED       CONFIRMED
# 1737       CANDIDATE       CANDIDATE
# 1738       CONFIRMED  FALSE POSITIVE
# 1739  FALSE POSITIVE       CONFIRMED
# 1740  FALSE POSITIVE  FALSE POSITIVE
# 1741       CONFIRMED       CANDIDATE
# 1742  FALSE POSITIVE  FALSE POSITIVE
# 1743       CONFIRMED       CONFIRMED
# 1744  FALSE POSITIVE  FALSE POSITIVE
# 1745       CONFIRMED       CONFIRMED
# 1746  FALSE POSITIVE       CONFIRMED
# 1747  FALSE POSITIVE  FALSE POSITIVE
#
# [1748 rows x 2 columns]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
params = {'penalty': ['l2', 'none']}

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(classifier, params, cv=5, verbose=0)

# %%
# Train the model with GridSearch
c
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='newton-cg',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='warn', n_jobs=None, param_grid={'penalty': ['l2', 'none']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'penalty': 'l2'}
# 0.5826816707991608

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Logistic_Regression.sav'
joblib.dump(clf, filename)
# Out:
# ['Logistic_Regression.sav']
